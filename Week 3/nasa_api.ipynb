# %% [markdown]
# # NASA API

# %% [markdown]
# ## CME

# %%
import requests # type: ignore
import json

nasa_base_url = "https://api.nasa.gov/DONKI/CME"

nasa_api_key = "AIzaSyCzcIoiPLIDToTv4erLyuMaMEzwhbMn7hA"
start_date = "2019-06-12"
end_date = "2020-07-12"

# nasa_url = f"{nasa_base_url}?startDate={start_date}&endDate={end_date}&api_key={nasa_api_key}"
nasa_url = "https://api.nasa.gov/DONKI/CME?startDate={start_date}&endDate={end_date}&api_key=DEMO_KEY"

nasa_response = requests.get(nasa_url)
nasa_response.status_code
nasa_response.json()
# Out:
# [{'activityID': '2024-05-22T03:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-05-22T03:36Z',
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/31141/-1',
#   'note': 'This CME is visible to the south/southeast in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is likely far-sided as there are no source signatures visible on the Earth-facing disk at the time of this event.',
#   'submissionTime': '2024-05-24T18:58Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-05-22T14:46Z',
#     'latitude': -51.0,
#     'longitude': 163.0,
#     'halfAngle': 34.0,
#     'speed': 306.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
# ...

# %% [markdown]
# ## CME Analysis

# %%
anal_base_url = "https://api.nasa.gov/DONKI/CME"

# ?startDate=2016-09-01&endDate=2016-09-30&mostAccurateOnly=true&speed=500&halfAngle=30&catalog=ALL&api_key=DEMO_KEY
api_key = "kScoLL6FcOgyimFoIlGsMA8l4RS521PyKrZOM9sn"
start_date = "2016-12-01" 
end_date = "2016-12-30"

anal_url2 = f"{anal_base_url}?startDate=2016-09-01&endDate=2016-09-30&api_key=DEMO_KEY"
anal_url = f"{anal_base_url}?startDate={start_date}&endDate={end_date}&api_key={api_key}"

anal_response = requests.get(anal_url)
anal_response2 = requests.get(anal_url2)

analysis = anal_response.json()
analysis2 = anal_response2.json
anal_response.json()

# %%
anal_response2.json()

# %% [markdown]
# # Epic API
# ## Retrievable Metadata

# %%
import requests
import json

earth_base_url = "https://api.nasa.gov/EPIC/api/natural/date/2019-03-30"

api_key = "kScoLL6FcOgyimFoIlGsMA8l4RS521PyKrZOM9sn"

earth_url = f"{earth_base_url}?api_key={api_key}"
assets_response = requests.get(earth_url)
assets_response.status_code
assets = assets_response.json()
assets

# %% [markdown]
# # Nasa Image and Video Lib

# %%
lib_base_url  = "https://images-api.nasa.gov"

id_num  = 10
search_url = f"{lib_base_url}/search?q={id_num}" 

search_response = requests.get(search_url)
search_response.status_code
search = search_response.json()
search

# %%
lib_base_url  = "https://images-api.nasa.gov"

id_num  = 1
search_url = f"{lib_base_url}/meatdata/{id_num}"

search_response = requests.get(search_url)
search_response.status_code
# search = search_response.json()
# search

# %% [markdown]
# # Mars Rover
# ## By Martian Sol

# %%
martian_base_url = "https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos"

sol = 1000
camera = "fhaz"
api_key = "kScoLL6FcOgyimFoIlGsMA8l4RS521PyKrZOM9sn"

martian_url = f"{martian_base_url}?sol={sol}&camera={camera}&api_key={api_key}"

martian_response = requests.get(martian_url)
martian_response.status_code
martian = martian_response.json()
martian
